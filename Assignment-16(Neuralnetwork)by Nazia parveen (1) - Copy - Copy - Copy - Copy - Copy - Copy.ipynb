# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\mohammed nouman\anaconda3\lib\site-packages (2.6.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\mohammed nouman\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: clang~=5.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.41.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: keras~=2.6 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (3.19.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wheel~=0.35 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.6.20)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mohammed nouman\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)

# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy  as np

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
#Part 1 - Data Preprocessing
#Importing the dataset¶

# %%
dataset = pd.read_csv("D:\\Data Science-ExcelR\\Data Sceince-Tahera\\gas_turbines.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
#Splitting the dataset into the Training set and Test set¶

# %%
# !pip install sklearn.model
# Out:
# Collecting sklearn.model
#   Downloading sklearn_model-0.0.6-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: pandas in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from sklearn.model) (1.3.3)
# Collecting scikit-learn>=0.22
#   Downloading scikit_learn-1.0.1-cp38-cp38-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from scikit-learn>=0.22->sklearn.model) (1.18.5)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from scikit-learn>=0.22->sklearn.model) (1.7.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from pandas->sklearn.model) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from pandas->sklearn.model) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mohammed nouman\anaconda3\envs\tensorflow_env\lib\site-packages (from python-dateutil>=2.7.3->pandas->sklearn.model) (1.16.0)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn.model
# Successfully installed joblib-1.1.0 scikit-learn-1.0.1 sklearn.model threadpoolctl-3.0.0

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Part 2 - Building the ANN¶

# %%
#Initializing the ANN

ann = tf.keras.models.Sequential()

# %%
#Adding the input layer and the first hidden layer¶

ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
#Adding the second hidden layer

ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
#Adding the output layer¶

ann.add(tf.keras.layers.Dense(units=1))
#Part 3 - Training the ANN
#Compiling the ANN

ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
#Training the ANN model on the Training set¶

ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 376/376 [==============================] - 1s 3ms/step - loss: 4975.3867
# Epoch 2/100
# 376/376 [==============================] - 1s 3ms/step - loss: 110.8888
# Epoch 3/100
# 376/376 [==============================] - 1s 3ms/step - loss: 109.8854
# Epoch 4/100
# 376/376 [==============================] - 1s 3ms/step - loss: 108.6473
# Epoch 5/100
# 376/376 [==============================] - 1s 3ms/step - loss: 107.0270
# Epoch 6/100
# 376/376 [==============================] - 1s 3ms/step - loss: 105.3959
# Epoch 7/100
# 376/376 [==============================] - 1s 3ms/step - loss: 103.5417
# Epoch 8/100
# 376/376 [==============================] - 1s 3ms/step - loss: 101.0381
# Epoch 9/100
# 376/376 [==============================] - 1s 3ms/step - loss: 98.7572
# Epoch 10/100
# 376/376 [==============================] - 1s 3ms/step - loss: 95.6707
# Epoch 11/100
# 376/376 [==============================] - 1s 3ms/step - loss: 92.0522
# Epoch 12/100
# 376/376 [==============================] - 1s 3ms/step - loss: 88.2093
# Epoch 13/100
# 376/376 [==============================] - 1s 3ms/step - loss: 83.0802
# Epoch 14/100
# 376/376 [==============================] - 1s 3ms/step - loss: 70.6965
# Epoch 15/100
# 376/376 [==============================] - 1s 3ms/step - loss: 58.8372
# Epoch 16/100
# 376/376 [==============================] - 1s 3ms/step - loss: 57.5075
# Epoch 17/100
# 376/376 [==============================] - 1s 3ms/step - loss: 55.4568
# Epoch 18/100
# 376/376 [==============================] - 1s 3ms/step - loss: 55.6119
# Epoch 19/100
# 376/376 [==============================] - 1s 3ms/step - loss: 54.6004
# Epoch 20/100
# 376/376 [==============================] - 1s 3ms/step - loss: 54.4521
# Epoch 21/100
# 376/376 [==============================] - 1s 3ms/step - loss: 53.5370
# Epoch 22/100
# 376/376 [==============================] - 1s 3ms/step - loss: 53.5239
# Epoch 23/100
# 376/376 [==============================] - 1s 3ms/step - loss: 33.7625
# Epoch 57/100
# 376/376 [==============================] - 1s 3ms/step - loss: 32.6543
# Epoch 58/100
# 376/376 [==============================] - 1s 3ms/step - loss: 31.9805
# Epoch 59/100
# 376/376 [==============================] - 1s 4ms/step - loss: 31.4115
# Epoch 60/100
# 376/376 [==============================] - 1s 3ms/step - loss: 29.9724
# Epoch 61/100
# 376/376 [==============================] - 1s 3ms/step - loss: 29.4870
# Epoch 62/100
# 376/376 [==============================] - 1s 4ms/step - loss: 29.6186
# Epoch 63/100
# 376/376 [==============================] - 1s 4ms/step - loss: 28.7963
# Epoch 64/100
# 376/376 [==============================] - 1s 4ms/step - loss: 28.2885
# Epoch 65/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.6702
# Epoch 66/100
# 376/376 [==============================] - 1s 3ms/step - loss: 28.5787
# Epoch 67/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.7299
# Epoch 68/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.1548
# Epoch 69/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.3512
# Epoch 70/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.1580
# Epoch 71/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.5005
# Epoch 72/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.3206: 0s - los
# Epoch 73/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.0924
# Epoch 74/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.4018
# Epoch 75/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.3635
# Epoch 76/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.5939
# Epoch 77/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.8696
# Epoch 78/100
# 376/376 [==============================] - 1s 3ms/step - loss: 27.0743
# Epoch 79/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.7271
# Epoch 80/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.3572
# Epoch 81/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.7816
# Epoch 82/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.6290
# Epoch 83/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.4973
# Epoch 84/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.2555
# Epoch 85/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.2535
# Epoch 86/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.4918
# Epoch 87/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.7092
# Epoch 88/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.4678
# Epoch 89/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.5467
# Epoch 90/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.2847
# Epoch 91/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.3934
# Epoch 92/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.2614
# Epoch 93/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.2539
# Epoch 94/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.4659
# Epoch 95/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.1727
# Epoch 96/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.4900
# Epoch 97/100
# 376/376 [==============================] - 1s 3ms/step - loss: 25.9655
# Epoch 98/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.1470
# Epoch 99/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.9177
# Epoch 100/100
# 376/376 [==============================] - 1s 3ms/step - loss: 26.8568

# %%
#Predicting the results of the Test set¶
y_pred = ann.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[77.24 77.04]
#  [70.04 70.77]
#  [66.01 65.65]
#  ...
#  [71.02 65.61]
#  [74.33 72.3 ]
#  [68.54 65.06]]
